# %%
from collections import Counter #count word occurrences
import pandas as pd

# %%
file_path = "Processed_Reviews.csv"
df = pd.read_csv(file_path)
df.head()
# Out:
#                                               Review  \
# 0  The product arrived on time. Packaging was gre...
# 1           THIS PRODUCT IS JUST AMAZING! I LOVE IT.
# 2  I bought this phone for $799, and it has a 120...
# 3  Wow!!! This product is awesome... but a bit ex...
# 4                The laptop works perfectly fine.
#
#                                           lowercased  \
# 0  the product arrived on time. packaging was gre...
# 1           this product is just amazing! i love it.
# 2  i bought this phone for $799, and it has a 120...
# 3  wow!!! this product is awesome... but a bit ex...
# 4                the laptop works perfectly fine.
#
#                                         urls_removed  \
# 0  the product arrived on time. packaging was gre...
# 1           this product is just amazing! i love it.
# 2  i bought this phone for $799, and it has a 120...
# 3  wow!!! this product is awesome... but a bit ex...
# 4                the laptop works perfectly fine.
#
#                                         html_removed  \
# 0  the product arrived on time. packaging was gre...
# 1           this product is just amazing! i love it.
# 2  i bought this phone for $799, and it has a 120...
# 3  wow!!! this product is awesome... but a bit ex...
# 4                the laptop works perfectly fine.
#
#                                       emojis_removed  \
# 0  the product arrived on time. packaging was gre...
# 1           this product is just amazing! i love it.
# 2  i bought this phone for $799, and it has a 120...
# 3  wow!!! this product is awesome... but a bit ex...
# 4                the laptop works perfectly fine.
#
#                                      slangs_replaced  \
# 0  the product arrived on time. packaging was gre...
# 1           this product is just amazing! i love it.
# 2  i bought this phone for $799, and it has a 120...
# 3  wow!!! this product is awesome... but a bit ex...
# 4                the laptop works perfectly fine.
#
#                                contractions_replaced  \
# 0  the product arrived on time. packaging was gre...
# 1           this product is just amazing! i love it.
# 2  i bought this phone for $799, and it has a 120...
# 3  wow!!! this product is awesome... but a bit ex...
# 4                the laptop works perfectly fine.
#
#                                 punctuations_removed  \
# 0  the product arrived on time packaging was grea...
# 1             this product is just amazing i love it
# 2  i bought this phone for 799 and it has a 120hz...
# 3    wow this product is awesome but a bit expensive
# 4                 the laptop works perfectly fine
#
#                                      numbers_removed  \
# 0  the product arrived on time packaging was grea...
# 1             this product is just amazing i love it
# 2  i bought this phone for  and it has a hz displ...
# 3    wow this product is awesome but a bit expensive
# 4                 the laptop works perfectly fine
#
#                                   spelling_corrected  \
# 0  the product arrived on time packaging was grea...
# 1             this product is just amazing i love it
# 2  i bought this phone for  and it has a hz displ...
# 3    wow this product is awesome but a bit expensive
# 4                 the laptop works perfectly fine
#
#                                    stopwords_removed  \
# 0  product arrived time packaging great quality a...
# 1                               product amazing love
# 2              bought phone hz display totally worth
# 3                  wow product awesome bit expensive
# 4                        laptop works perfectly fine
#
#                                   stemmed_words  \
# 0  product arriv time packag great qualiti amaz
# 1                             product amaz love
# 2           bought phone hz display total worth
# 3                 wow product awesom bit expens
# 4                    laptop work perfectli fine
#
#                                           lemmatized  \
# 0  product arrive time packaging great quality am...
# 1                                 product amaze love
# 2                 buy phone hz display totally worth
# 3                  wow product awesome bit expensive
# 4                         laptop work perfectly fine
#
#                                            tokenized
# 0  ['product', 'arrive', 'time', 'packaging', 'gr...
# 1                       ['product', 'amaze', 'love']
# 2  ['buy', 'phone', 'hz', 'display', 'totally', '...
# 3  ['wow', 'product', 'awesome', 'bit', 'expensive']
# 4            ['laptop', 'work', 'perfectly', 'fine']

# %%
tokenized_reviews = df['tokenized'].dropna().apply(eval)

# %%
all_words = [word for review in tokenized_reviews for word in review]
unique_words = list(set(all_words))

# %%
print(unique_words)
# Out:
# ['ever', 'love', 'time', 'packaging', 'shoe', 'phone', 'fit', 'short', 'happy', 'expect', 'perfectly', 'can', 'god', 'fast', 'excellent', 'worth', 'amazing', 'life', 'great', 'display', 'buy', 'quality', 'hz', 'laptop', 'believe', 'check', 'honest', 'totally', 'much', 'fine', 'charge', 'best', 'product', 'nicely', 'cable', 'wow', 'amaze', 'detail', 'not', 'good', 'oh', 'full', 'jog', 'comfortable', 'expensive', 'work', 'bit', 'arrive', 'use', 'battery', 'delivery', 'awesome', 'purchase']

# %%
word_freq = Counter(all_words)
sorted_word_freq = dict(sorted(word_freq.items(), key=lambda item: item[1], reverse=True))

# %%
document_vectors = []
for review in tokenized_reviews:
    document_vector = [1 if word in review else 0 for word in sorted_word_freq.keys()]
    document_vectors.append(document_vector)

# %%
doc_vectors_df = pd.DataFrame(document_vectors, columns=sorted_word_freq.keys())

# %%
doc_vectors_df.to_csv("document_vectors.csv", index=False)

# %%
word_freq_df = pd.DataFrame(list(sorted_word_freq.items()), columns=["Word", "Frequency"])
print("Word Frequency Table:")
print(word_freq_df)
# Out:
# Word Frequency Table:
#            Word  Frequency
# 0       product          7
# 1       quality          3
# 2         great          2
# 3       amazing          2
# 4          love          2
# 5       awesome          2
# 6          work          2
# 7     perfectly          2
# 8          life          2
# 9        expect          2
# 10       arrive          1
# 11         time          1
# 12    packaging          1
# 13        amaze          1
# 14          buy          1
# 15        phone          1
# 16           hz          1
# 17      display          1
# 18      totally          1
# 19        worth          1
# 20          wow          1
# 21          bit          1
# 22    expensive          1
# 23       laptop          1
# 24         fine          1
# 25        check          1
# 26         full          1
# 27       detail          1
# 28     purchase          1
# 29        happy          1
# 30      battery          1
# 31    excellent          1
# 32       charge          1
# 33        cable          1
# 34        short          1
# 35          can          1
# 36          not          1
# 37      believe          1
# 38         good          1
# 39         fast          1
# 40     delivery          1
# 41       honest          1
# 42         much          1
# 43           oh          1
# 44          god          1
# 45         best          1
# 46         ever          1
# 47          use          1
# 48         shoe          1
# 49  comfortable          1
# 50          fit          1
# 51       nicely          1
# 52          jog          1
